# %%
# initial importing
from eggp import EGGP
from symregg import SymRegg
from reggression import Reggression
from pysr import PySRRegressor
from pyoperon.sklearn import SymbolicRegressor
import bingo.symbolic_regression.symbolic_regressor as bingo # import SymbolicRegressor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
df = pd.read_csv("nikuradse_1.csv")
X = df[['r_k','log_Re']].values
y = df['target'].values
df.head()
# Out:
#      r_k  log_Re  target
# 0  507.0   4.114   0.456
# 1  507.0   4.230   0.438
# 2  507.0   4.322   0.417
# 3  507.0   4.362   0.407
# 4  507.0   4.362   0.403

# %%
def plot_error(expr, X, y):
  x = X
  t = eval(expr.loc[0, 'Parameters'])
  yhat = eval(expr.loc[0, 'Numpy'])
  plt.plot(yhat, y, '.')

def plot_error_seg(expr, X, y):
  vals = np.unique(X[:,0])
  for xi in vals:
    ix = X[:,0]==xi
    plot_error(expr, X[ix,:], y[ix])

# %%
reg = EGGP(maxSize=25, gen=200, nPop=300, nonterminals="add,sub,mul,div,powerabs,recip", loss="MSE",
           dumpTo="niku1_example.egraph")
reg.fit(X,y)
# Out:
# EGGP(dumpTo='niku1_example.egraph', gen=200, generational=0, maxSize=25,
#      nPop=300, nonterminals='add,sub,mul,div,powerabs,recip', simplify=0,
#      trace=0)

# %%
reg.results
# Out:
#     id  view                                         Expression  \
# 0    0     0                                 0.5304279005524852
# 1    1     0                   (Abs(x0) ^ -0.15423549498311556)
# 2    2     0  (Abs((5.505885914129079 / x0)) ^ 0.26264387381...
# 3    3     0  (Abs(Recip((x0 * -0.18159715833655263))) ^ 0.2...
# 4    4     0  (1.5617885360796704 * ((Abs(x0) ^ -0.237209358...
# 5    5     0  (-0.4386992726413078 + (Abs((1.120260181678851...
# 6    6     0  (0.5496094132558067 * (Abs((1.2350246084456522...
# 7    7     0  (Abs((((x1 / x0) + (Abs(-0.39390086677663116) ...
# 8    8     0  (Abs((((x1 / x0) + (6.574807487895372 / (Abs(x...
# 9    9     0  (Abs((-1.250370646609018 * ((x1 / x0) + (x0 / ...
# 10  10     0  (Abs((-1.2874756981286137 * ((x1 / x0) + (x0 /...
# 11  11     0  (Abs((1.8560342460981416 * ((x1 / (x0 + x1)) +...
# 12  12     0  (Abs((1.1677241019808207 * ((-3.33169635893208...
#
#                                                 Numpy  \
# 0                                                t[0]
# 1                             np.abs(x[:, 0]) ** t[0]
# 2                    np.abs((t[0] / x[:, 0])) ** t[1]
# 3     np.abs(np.reciprocal((x[:, 0] * t[0]))) ** t[1]
# 4           (t[0] * (np.abs(x[:, 0]) ** t[1] + t[2]))
# 5   (t[0] + np.abs((t[1] / np.abs(x[:, 0]) ** t[2]...
# 6   (t[0] * np.abs((t[1] / np.reciprocal(np.abs(x[...
# 7   np.abs((((x[:, 1] / x[:, 0]) + np.abs(t[0]) **...
# 8   np.abs((((x[:, 1] / x[:, 0]) + (t[0] / np.abs(...
# 9   np.abs((t[0] * ((x[:, 1] / x[:, 0]) + (x[:, 0]...
# 10  np.abs((t[0] * ((x[:, 1] / x[:, 0]) + (x[:, 0]...
# 11  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])...
# 12  np.abs((t[0] * ((t[1] / (x[:, 1] + t[2])) + ((...
#
#                                                 theta  size  loss_train  \
# 0                                  0.5304279005524852     1    0.025533
# 1                                -0.15423549498311556     4    0.005466
# 2                5.505885914129079;0.2626438738181238     6    0.001309
# 3             -0.18159715833655263;0.2626695117346605     7    0.001309
# 4   1.5617885360796704;-0.23720935806326995;-3.532...     8    0.001303
# 5   -0.4386992726413078;1.1202601816788518;2.83980...    11    0.001038
# 6   0.5496094132558067;1.2350246084456522;-5.27226...    12    0.000989
# 7   -0.39390086677663116;1.321661268963687;0.30908...    13    0.000930
# 8   6.574807487895372;-1.2129527927159234;0.285850...    15    0.000622
# 9   -1.250370646609018;1.5129127019671176;0.289309...    17    0.000352
# 10  -1.2874756981286137;-1.9714339606456395;0.2918...    19    0.000317
# 11  1.8560342460981416;-0.9901810748046391;1.53528...    22    0.000257
# 12  1.1677241019808207;-3.3316963589320875e-2;-0.1...    26    0.000242
#
#     loss_val  loss_test   maxloss      R2_train        R2_val       R2_test  \
# 0   0.025533   0.025533  0.025533  2.664535e-15  2.664535e-15  2.664535e-15
# 1   0.005466   0.005466  0.005466  7.859255e-01  7.859255e-01  7.859255e-01
# 2   0.001309   0.001309  0.001309  9.487450e-01  9.487450e-01  9.487450e-01
# 3   0.001309   0.001309  0.001309  9.487450e-01  9.487450e-01  9.487450e-01
# 4   0.001303   0.001303  0.001303  9.489497e-01  9.489497e-01  9.489497e-01
# 5   0.001038   0.001038  0.001038  9.593375e-01  9.593375e-01  9.593375e-01
# 6   0.000989   0.000989  0.000989  9.612560e-01  9.612560e-01  9.612560e-01
# 7   0.000930   0.000930  0.000930  9.635758e-01  9.635758e-01  9.635758e-01
# 8   0.000622   0.000622  0.000622  9.756304e-01  9.756304e-01  9.756304e-01
# 9   0.000352   0.000352  0.000352  9.862282e-01  9.862282e-01  9.862282e-01
# 10  0.000317   0.000317  0.000317  9.875921e-01  9.875921e-01  9.875921e-01
# 11  0.000257   0.000257  0.000257  9.899347e-01  9.899347e-01  9.899347e-01
# 12  0.000242   0.000242  0.000242  9.905261e-01  9.905261e-01  9.905261e-01
#
#     mdl_train    mdl_val   mdl_test
# 0    0.025533   0.025533   0.025533
# 1    3.301303   3.301303   3.301303
# 2    6.932781   6.932781   6.932781
# 3    9.657936   9.657936   9.657936
# 4   11.267369  11.267369  11.267369
# 5   16.126873  16.126873  16.126873
# 6   19.460091  19.460091  19.460091
# 7   21.405942  21.405942  21.405942
# 8   25.297454  25.297454  25.297454
# 9   29.189004  29.189004  29.189004
# 10  33.080789  33.080789  33.080789
# 11  36.972550  36.972550  36.972550
# 12  44.756175  44.756175  44.756175

# %%
egraph = Reggression(dataset="nikuradse_1.csv", loadFrom="niku1_example.egraph")
# Out:
# Calculating DL...
# Welcome to r🥚ression

# %%
# Let's get the top-10
egraph.top(5)
# Out:
#        Id                                         Expression  \
# 0  113965  (Abs((t0 * ((t1 / (x1 + t2)) + ((x1 / x0) + (x...
# 1  263973  (Abs((t0 * ((x1 / (x0 + x1)) + (x0 / (Abs(x1) ...
# 2  261605  (Abs((t0 * ((x1 / (x0 + x1)) + (x0 / (Abs(x1) ...
# 3  215053  (Abs((t0 * ((x1 / ((x1 + t1) + x0)) + ((x0 + t...
# 4  177203  (Abs((t0 * ((x1 / (x0 + x1)) + ((x0 + t1) / (A...
#
#                                                Numpy   Fitness  \
# 0  np.abs((t[0] * ((t[1] / (x[:, 1] + t[2])) + ((... -0.000242
# 1  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])... -0.000250
# 2  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])... -0.000254
# 3  np.abs((t[0] * ((x[:, 1] / ((x[:, 1] + t[1]) +... -0.000256
# 4  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])... -0.000256
#
#                                           Parameters  Size         DL
# 0  [1.1677241019808207, -3.3316963589320875e-2, -...    23  44.756175
# 1  [-1.850112121387336, 0.5338286768068258, 0.313...    23  44.756183
# 2  [1.8457222559709123, 0.530639707948381, 0.3286...    23  44.756188
# 3  [-1.9260000686316399, 0.7810666521279049, -1.1...    23  44.756189
# 4  [-1.8451484577340886, -0.2594788694809811, -0....    23  44.756190

# %%
# Let's check the top 5 with size <= 10
egraph.top(5, filters=["size <= 10"])
# Out:
#        Id                                       Expression  \
# 0  156535  (t0 * (Abs((t1 / Recip((Abs(x0) ^ t2)))) ^ x1))
# 1   60350         (t0 + (Abs((t1 / (Abs(x0) ^ t2))) ^ x1))
# 2   41153         ((Abs(((Abs(x0) ^ t0) * t1)) ^ x1) + t2)
# 3   75545  (Abs((t0 * ((Abs(t1) ^ x1) + Recip(x0)))) ^ t2)
# 4  102328  (Abs(((Recip(x0) + (Abs(t0) ^ x1)) * x1)) ^ t1)
#
#                                                Numpy   Fitness  \
# 0  (t[0] * np.abs((t[1] / np.reciprocal(np.abs(x[... -0.000989
# 1  (t[0] + np.abs((t[1] / np.abs(x[:, 0]) ** t[2]... -0.001038
# 2  (np.abs((np.abs(x[:, 0]) ** t[0] * t[1])) ** x... -0.001055
# 3  np.abs((t[0] * (np.abs(t[1]) ** x[:, 1] + np.r... -0.001096
# 4  np.abs(((np.reciprocal(x[:, 0]) + np.abs(t[0])... -0.001175
#
#                                           Parameters  Size         DL
# 0  [0.5496094132558067, 1.2350246084456522, -5.27...    10  19.460091
# 1  [-0.4386992726413078, 1.1202601816788518, 2.83...     9  16.126873
# 2  [-2.939911516511545e-2, 1.1196463719327474, -0...     9  16.126891
# 3  [-5.82437962925986, -0.23013259949333686, 0.27...    10  19.460197
# 4        [-0.25278559440790005, 0.26457073496600125]    10  19.460277

# %%
# what about these expressions where x0 is scaled by t0?
egraph.top(5, filters=["size <= 10"], pattern="x0 * t0")
# Out:
#        Id                                       Expression  \
# 0   39086         ((Abs((Abs((x0 * t0)) ^ t1)) ^ t2) + t3)
# 1   31977                     ((Abs((x0 * t0)) ^ t1) + t2)
# 2   32101  (Abs(Recip((x0 * t0))) ^ ((Abs(x0) ^ t1) + t2))
# 3  240574       (Abs(Recip(((x0 * t0) * (x0 + t1)))) ^ t2)
# 4  226801       (Abs(Recip((Recip(x0) - (x0 * t0)))) ^ t1)
#
#                                                Numpy   Fitness  \
# 0  (np.abs(np.abs((x[:, 0] * t[0])) ** t[1]) ** t... -0.001304
# 1          (np.abs((x[:, 0] * t[0])) ** t[1] + t[2]) -0.001305
# 2  np.abs(np.reciprocal((x[:, 0] * t[0]))) ** (np... -0.001306
# 3  np.abs(np.reciprocal(((x[:, 0] * t[0]) * (x[:,... -0.001308
# 4  np.abs(np.reciprocal((np.reciprocal(x[:, 0]) -... -0.001308
#
#                                           Parameters  Size         DL
# 0  [-0.1334676788374024, -0.4732675422315457, 0.4...     9  14.486245
# 1  [-0.1695741545385248, -0.2499739132612616, -2....     7  11.267371
# 2  [0.17160585235854858, -1.6208587453095586, 0.2...    10  17.918901
# 3  [-3.160605277258985e-2, 0.507760919277795, 0.1...    10  17.918903
# 4          [-0.175667023284039, 0.26564071255682387]     9  16.127143

# %%
# Now let's retrieve the top 5 with size <= 10 and not having the pattern |v0|^v1
egraph.top(5, filters=["size <= 10"], pattern="(v0 |**| v1) + v3", negate=True)
# Out:
#        Id                                       Expression  \
# 0  156535  (t0 * (Abs((t1 / Recip((Abs(x0) ^ t2)))) ^ x1))
# 1   60350         (t0 + (Abs((t1 / (Abs(x0) ^ t2))) ^ x1))
# 2  102328  (Abs(((Recip(x0) + (Abs(t0) ^ x1)) * x1)) ^ t1)
# 3   77687  (Abs(((Recip(x0) + (Abs(t0) ^ x1)) * t1)) ^ t2)
# 4  133436  (Abs((Recip(((Abs(t0) ^ x1) * x0)) * t1)) ^ t2)
#
#                                                Numpy   Fitness  \
# 0  (t[0] * np.abs((t[1] / np.reciprocal(np.abs(x[... -0.000989
# 1  (t[0] + np.abs((t[1] / np.abs(x[:, 0]) ** t[2]... -0.001038
# 2  np.abs(((np.reciprocal(x[:, 0]) + np.abs(t[0])... -0.001175
# 3  np.abs(((np.reciprocal(x[:, 0]) + np.abs(t[0])... -0.001180
# 4  np.abs((np.reciprocal((np.abs(t[0]) ** x[:, 1]... -0.001281
#
#                                           Parameters  Size         DL
# 0  [0.5496094132558067, 1.2350246084456522, -5.27...    10  19.460091
# 1  [-0.4386992726413078, 1.1202601816788518, 2.83...     9  16.126873
# 2        [-0.25278559440790005, 0.26457073496600125]    10  19.460277
# 3  [0.25018363226713464, -5.350072947273268, 0.27...    10  19.460281
# 4  [0.9418305981635068, 4.152083023852496, 0.2643...    10  17.918876

# %%
modular = egraph.top(5, pattern="v0 |**| v0")
modular.Expression.values
# Out:
# array(['(Abs((t0 * ((x1 / (x0 + x1)) + ((x0 + t1) / (Abs((Abs(x1) ^ x1)) ^ t2))))) ^ t3)',
#        '(Abs((t0 * ((x1 / (x0 + x1)) + (((x0 + Recip(x0)) + t1) / (Abs((Abs(x1) ^ x1)) ^ t2))))) ^ t3)',
#        '(Abs((t0 * ((x1 / (x0 + x1)) + (((x0 + (Abs(t1) ^ x1)) + t2) / (Abs((Abs(x1) ^ x1)) ^ t3))))) ^ t4)',
#        '(Abs((t0 * ((x1 / ((x0 * t1) + x1)) + ((x0 + t2) / (Abs((Abs(x1) ^ x1)) ^ t3))))) ^ t4)',
#        '(Abs((t0 * ((x1 / (x0 + x1)) + (((Recip((t1 / x0)) + x0) + t2) / (Abs((Abs(x1) ^ x1)) ^ t3))))) ^ t4)'],
#       dtype=object)

# %%
# Now let's find expressions with this pattern at the root (so the root should be ^)
egraph.top(5, filters=["size <= 10"], pattern="x0 |**| v1", isRoot=True)
# Out:
#        Id                                Expression  \
# 0   97002              (Abs(x0) ^ (t0 + (t1 / x0)))
# 1   91859         (Abs(x0) ^ (t0 * (Abs(x0) ^ t1)))
# 2  114681  (Abs(x0) ^ (t0 + (x1 / (Abs(x1) ^ x1))))
# 3   29855         (Abs(x0) ^ ((Abs(t0) ^ x1) + t1))
# 4      88                            (Abs(x0) ^ t0)
#
#                                                Numpy   Fitness  \
# 0       np.abs(x[:, 0]) ** (t[0] + (t[1] / x[:, 0])) -0.001524
# 1  np.abs(x[:, 0]) ** (t[0] * np.abs(x[:, 0]) ** ... -0.001683
# 2  np.abs(x[:, 0]) ** (t[0] + (x[:, 1] / np.abs(x... -0.005250
# 3  np.abs(x[:, 0]) ** (np.abs(t[0]) ** x[:, 1] + ... -0.005316
# 4                            np.abs(x[:, 0]) ** t[0] -0.005466
#
#                                      Parameters  Size         DL
# 0      [-0.181860344786348, 1.3340605415320728]     7  11.267590
# 1  [-7.199244927916311e-2, 0.16872823291685604]     7   9.705744
# 2                        [-0.15870296360007233]     9  16.131086
# 3    [-0.9906831324555236, -1.1085838930849277]     7  11.271382
# 4                        [-0.15423549498311556]     3   3.301303

# %%
# let's test other filters
egraph.top(5, filters=["size < 10", "parameters > 1", "cost < 15"], criteria="dl")
# Out:
#        Id                  Expression  \
# 0   11961  (Abs(t0) ^ (Abs(x0) ^ t1))
# 1   10500  (Abs((Abs(x0) ^ t0)) ^ t1)
# 2   10823  (Abs((Abs(x1) ^ t0)) ^ t1)
# 3   21941  (Abs((Abs(x1) ^ t0)) ^ t1)
# 4  149058  (Abs(t0) ^ (Abs(x1) ^ t1))
#
#                                      Numpy   Fitness  \
# 0  np.abs(t[0]) ** np.abs(x[:, 0]) ** t[1] -0.002185
# 1  np.abs(np.abs(x[:, 0]) ** t[0]) ** t[1] -0.005466
# 2  np.abs(np.abs(x[:, 1]) ** t[0]) ** t[1] -0.024757
# 3  np.abs(np.abs(x[:, 1]) ** t[0]) ** t[1] -0.024757
# 4  np.abs(t[0]) ** np.abs(x[:, 1]) ** t[1] -0.024773
#
#                                     Parameters  Size        DL
# 0     [0.8950554917263657, 0.3998873718621791]     5  5.495246
# 1  [-4.752743041105169e-2, 3.2451853344285384]     5  5.498527
# 2    [-0.6604859809909795, 0.6029015723330173]     5  5.517819
# 3    [0.5382390120422188, -0.7398247996489675]     5  5.517819
# 4     [0.7906855509387621, 0.6215779288417661]     5  5.517834

# %%
# query for the top patterns by the following criteria
# from the top 5000 expressions, with at least 1000 of frequency
# show the top 25 distributions sorted by avg. fitness 
# and with size between 8 and 15
egraph.distribution(filters=["size < 15"], 
                    limitedAt=5, dsc=True, 
                    byFitness=True, atLeast=100, 
                    fromTop=1000)
# Out:
#                                             Pattern  Count    AvgFit
# 0  ((t0 * (v0 + (v1 / (x1 |^| (v2 + x1))))) |^| v3)    133 -0.000348
# 1  ((t0 * (v0 + (v1 / (v2 |^| (v3 + x1))))) |^| v4)    136 -0.000348
# 2  ((v0 * (v1 + (v2 / (x1 |^| (v3 + x1))))) |^| v4)    136 -0.000350
# 3  ((v0 * (v1 + (v2 / (v3 |^| (v4 + x1))))) |^| v5)    139 -0.000350
# 4  ((v0 * (v1 + (x0 / (v2 |^| (v3 + v4))))) |^| v5)    103 -0.000364

# %%
egraph.countPattern("v0 |**| v1")
# Out:
# 'v0 |**| v1 appears in 143420 equations.'

# %%
# inspect the subtrees
egraph.subtrees(156535)
# Out:
#        Id                                       Expression  \
# 0  156535  (t0 * (Abs((t1 / Recip((Abs(x0) ^ t2)))) ^ x1))
# 1       3                                               t0
# 2  156534         (Abs((t0 / Recip((Abs(x0) ^ t1)))) ^ x1)
# 3   29502                     (t0 / Recip((Abs(x0) ^ t1)))
# 4       1                                               x1
# 5    1116                                               t0
# 6    2471                            Recip((Abs(x0) ^ t0))
# 7    2470                                   (Abs(x0) ^ t0)
# 8       0                                               x0
# 9    1122                                               t0
#
#                                                Numpy       Fitness  \
# 0  (t[0] * np.abs((t[1] / np.reciprocal(np.abs(x[...     -0.000989
# 1                                               t[0]     -0.025533
# 2  np.abs((t[0] / np.reciprocal(np.abs(x[:, 0]) *...           NaN
# 3    (t[0] / np.reciprocal(np.abs(x[:, 0]) ** t[1]))           NaN
# 4                                            x[:, 1]    -20.221664
# 5                                               t[0]           NaN
# 6             np.reciprocal(np.abs(x[:, 0]) ** t[0])           NaN
# 7                            np.abs(x[:, 0]) ** t[0]           NaN
# 8                                            x[:, 0] -44688.330824
# 9                                               t[0]           NaN
#
#                                           Parameters  Size            DL
# 0  [0.5496094132558067, 1.2350246084456522, -5.27...    10     19.460091
# 1                               [0.5304279005524852]     1      0.025533
# 2                                                NaN     8           NaN
# 3                                                NaN     6           NaN
# 4                                                 []     1     20.221664
# 5                                                NaN     1           NaN
# 6                                                NaN     4           NaN
# 7                                                NaN     3           NaN
# 8                                                 []     1  44688.330824
# 9                                                NaN     1           NaN

# %%
# (re) optimize the parameters
egraph.optimize(29502)
# Out:
#       Id                    Expression  \
# 0  29502  (t0 / Recip((Abs(x0) ^ t1)))
#
#                                              Numpy   Fitness  \
# 0  (t[0] / np.reciprocal(np.abs(x[:, 0]) ** t[1])) -0.001309
#
#                                    Parameters  Size        DL
# 0  [1.5619429635000823, -0.26236331367653726]     6  9.657937

# %%
# insert a new expression
egraph.insert("t0 + log(x1) * x0 * t1")
# Out:
#        Id                    Expression  \
# 0  266971  (t0 + ((Log(x1) * x0) * t1))
#
#                                            Numpy   Fitness  \
# 0  (t[0] + ((np.log(x[:, 1]) * x[:, 0]) * t[1])) -0.008553
#
#                                     Parameters  Size         DL
# 0  [0.6419790391210997, -4.967073701510399e-4]     8  14.342629

# %%
# show the Pareto front
pareto = egraph.pareto(byFitness=False)
pareto
# Out:
#         Id                                         Expression  \
# 0        3                                                 t0
# 7   192105  (Abs((Abs((Abs(x1) ^ x1)) ^ (Abs(x1) ^ t0))) ^...
# 11  211786  (Abs((((Abs((Abs(x0) ^ t0)) ^ t1) * (x0 * t2))...
# 13   25817  (Abs((t0 * (Abs(((x0 * ((x0 * t1) * x0)) * t2)...
# 15  158326  (Abs((t0 * (((Abs(((Abs((Abs(t1) ^ x1)) ^ t2) ...
# 17   78217  (t0 + (Abs(((Abs(((Abs((((Abs(x0) ^ t1) + t2) ...
# 19   32591  (t0 + (Abs((t1 / (t2 + ((x0 + (t3 + ((Abs(x0) ...
# 21   23271  ((Abs((((Abs(((Abs(x0) ^ t0) * t1)) ^ t2) + t3...
#
#                                                 Numpy   Fitness  \
# 0                                                t[0] -0.025533
# 7   np.abs(np.abs(np.abs(x[:, 1]) ** x[:, 1]) ** n... -0.024757
# 11  np.abs(((np.abs(np.abs(x[:, 0]) ** t[0]) ** t[... -0.001309
# 13  np.abs((t[0] * np.abs(((x[:, 0] * ((x[:, 0] * ... -0.001309
# 15  np.abs((t[0] * ((np.abs((np.abs(np.abs(t[1]) *... -0.024739
# 17  (t[0] + np.abs((np.abs((np.abs(((np.abs(x[:, 0... -0.001303
# 19  (t[0] + np.abs((t[1] / (t[2] + ((x[:, 0] + (t[... -0.001525
# 21  (np.abs(((np.abs((np.abs(x[:, 0]) ** t[0] * t[... -0.006716
#
#                                            Parameters  Size         DL
# 0                                [0.5304279005524852]     1   0.025533
# 7          [-1.0173914608453707, -0.4094313775915835]     9   9.912267
# 11  [-0.23042909745666487, -0.12628049060580165, -...    13  18.023135
# 13  [0.735083712755709, -3.0815045507851434e-2, -0...    15  20.795724
# 15  [0.6544810238072597, -0.33947444871399624, -0....    17  23.591743
# 17  [-0.48403822610222613, -0.19725718021955238, 0...    19  30.580624
# 19  [0.1670402832402912, -3.2158278633702175, -0.5...    21  33.799721
# 21  [-0.7521983778665375, -3.1345269140191705e-9, ...    23  37.023788

# %%
# plot the pareto front
pareto = egraph.pareto(byFitness=False)
plt.plot(pareto.DL.iloc[3:], pareto.Size.iloc[3:], '.', markersize=15)#, xlabel="DL", )

# %%
expr = egraph.insert("x0 ** (t0 + sqrt(x1))")
egraph.extractPattern(expr.Id.values[0])
# Out:
#                    Pattern  Count  AvgFit
# 0   (x0 ^ (t0 + Sqrt(x1)))      1     0.0
# 1   (x0 ^ (t0 + Sqrt(v0)))      1     0.0
# 2         (x0 ^ (t0 + v0))      1     0.0
# 3   (x0 ^ (v0 + Sqrt(x1)))      1     0.0
# 4   (x0 ^ (v0 + Sqrt(v1)))      1     0.0
# 5         (x0 ^ (v0 + v1))      1     0.0
# 6                (x0 ^ v0)      1     0.0
# 7   (v0 ^ (t0 + Sqrt(x1)))      1     0.0
# 8   (v0 ^ (t0 + Sqrt(v1)))      1     0.0
# 9         (v0 ^ (t0 + v1))      1     0.0
# 10  (v0 ^ (v1 + Sqrt(x1)))      1     0.0
# 11  (v0 ^ (v1 + Sqrt(v2)))      1     0.0
# 12        (v0 ^ (v1 + v2))      1     0.0
# 13               (v0 ^ v1)      1     0.0
# 14                      v0      1     0.0

# %%
egraph.distributionOfTokens(500)
# Out:
#         Pattern  Count    AvgFit
# 0            x0   1273 -0.000136
# 1            x1   2317 -0.000075
# 2            t0    502 -0.000346
# 3            t1    498 -0.000347
# 4            t2    472 -0.000345
# 5            t3    383 -0.000343
# 6            t4    173 -0.000346
# 7            t5     39 -0.000353
# 8            t6      4 -0.000357
# 9     Recip(v0)    205 -0.000320
# 10    (v0 + v1)   1929 -0.000090
# 11    (v0 - v1)     18 -0.000349
# 12    (v0 * v1)    867 -0.000199
# 13    (v0 / v1)   1196 -0.000145
# 14  (v0 |^| v1)   1151 -0.000151

# %%
top = egraph.top(1)
plot_error_seg(top, X, y)

# %%
# let's run other algorithms, starting with PySR
regPySR = PySRRegressor(verbosity=0)
regPySR.fit(X, y)
f = open("equations.pysr", "w")
for eq in regPySR.equations_.equation:
  print(f"{eq},,1.0", file=f)
f.close()
# Out:
# /home/olivetti/.local/pyenv/lib/python3.13/site-packages/pysr/sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(

# %%
# now Operon
regOp = SymbolicRegressor()
regOp.fit(X, y)
f = open("equations.operon", "w")
for eq in regOp.pareto_front_:
  eqstr = regOp.get_model_string(eq['tree'])
  print(f"{eqstr},,1.0", file=f)
f.close()

# %%
# and Bingo
regBingo = bingo.SymbolicRegressor(max_time=60)
regBingo.fit(X, y)
f = open("equations.bingo", "w")
for eq in regBingo.best_pop:
  print(f"{eq},,1.0", file=f)
f.close()
# Out:
# /home/olivetti/.local/pyenv/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:497: RuntimeWarning: overflow encountered in matmul
#   cov_x = invR @ invR.T
# /home/olivetti/.local/pyenv/lib/python3.13/site-packages/bingo/evaluation/fitness_function.py:25: RuntimeWarning: overflow encountered in square
#   return np.mean(np.square(vector))
# /home/olivetti/.local/pyenv/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:497: RuntimeWarning: invalid value encountered in matmul
#   cov_x = invR @ invR.T

# %%
egraph.importFromCSV("equations.bingo", True)
egraph.importFromCSV("equations.operon", True)
egraph.importFromCSV("equations.pysr", True)
# Out:
# ''

# %%
# let's save the results
egraph.save("newegg.egg");
# and reload to rebuild the database
egraph = Reggression(dataset="nikuradse_1.csv", loadFrom="newegg.egg", refit=True)
# Out:
# Calculating DL...
# Welcome to r🥚ression

# %%
egraph.top()
# Out:
#        Id                                         Expression  \
# 0  123543  (Abs((t0 * ((x1 / (x0 + x1)) + ((t1 / x0) + (x...
# 1  205478  (Abs((t0 * ((x1 / (x0 + x1)) + (x0 / (Abs(x1) ...
# 2  232161  (Abs((t0 * (((x1 + t1) / (x0 + x1)) + ((x0 + t...
# 3  221985  (Abs((Abs((t0 * ((x1 / (x0 + x1)) + (x0 / (Abs...
# 4  263106  (Abs((t0 * ((x1 / (x0 + x1)) + (x0 / (Abs(x1) ...
#
#                                                Numpy   Fitness  \
# 0  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])... -0.000254
# 1  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])... -0.000255
# 2  np.abs((t[0] * (((x[:, 1] + t[1]) / (x[:, 0] +... -0.000256
# 3  np.abs(np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x... -0.000257
# 4  np.abs((t[0] * ((x[:, 1] / (x[:, 0] + x[:, 1])... -0.000257
#
#                                           Parameters  Size         DL
# 0  [-1.9367786118093355, -0.17014418932107747, -0...    25  48.648008
# 1  [-1.8478237686816947, 1.5284968914270196, 0.32...    23  44.756188
# 2  [1.843531609389819, -1.1448324007903415e-2, -0...    21  40.864369
# 3  [-1.8217826053203743, 0.5849435071522083, -0.1...    23  44.756190
# 4  [-1.8385665951797117, 0.5193704596378709, 1.72...    23  44.756191

# %%
top = egraph.top(1)
plot_error_seg(top, X, y)

# %%
reg_graph = Reggression(dataset="nikuradse_1.csv", parseCSV="equations.operon")
reg_graph.importFromCSV("equations.bingo", True)
reg_graph.importFromCSV("equations.pysr", True)
# Out:
# Calculating DL...
# Welcome to r🥚ression
# ''

# %%
reg_graph.save("seed.egraph")
reg_graph = Reggression(dataset="nikuradse_1.csv", loadFrom="seed.egraph", refit=True)
reg_graph.save("seed.egraph")
reg_graph.top(5)
# Out:
# Calculating DL...
# Welcome to r🥚ression
#     Id                                         Expression  \
# 0  867  (((x1 - (t0 / x1)) / (x1 + (x0 / x1))) + (t1 /...
# 1  861  ((x1 / (((x0 / x1) + t0) + x1)) + (t1 / (x1 + ...
# 2  846              ((t0 / x1) + (x1 / ((t1 * x0) + t2)))
# 3  894  ((t0 / ((x1 + x1) + t1)) + ((x1 - (t2 / x1)) /...
# 4  903  ((t0 / ((x1 + x1) + t1)) + ((x1 - (t2 / x1)) /...
#
#                                                Numpy   Fitness  \
# 0  (((x[:, 1] - (t[0] / x[:, 1])) / (x[:, 1] + (x... -0.000824
# 1  ((x[:, 1] / (((x[:, 0] / x[:, 1]) + t[0]) + x[... -0.000939
# 2  ((t[0] / x[:, 1]) + (x[:, 1] / ((t[1] * x[:, 0... -0.000987
# 3  ((t[0] / ((x[:, 1] + x[:, 1]) + t[1])) + ((x[:... -0.001001
# 4  ((t[0] / ((x[:, 1] + x[:, 1]) + t[1])) + ((x[:... -0.001277
#
#                                           Parameters  Size         DL
# 0  [5.825659838707999, 1.1292171342834418, -1.160...    17  30.460735
# 1  [2.168170372995892, 1.5340484676404933, 0.6105...    15  24.142507
# 2  [1.2922190848724948, 0.1752177187982926, 7.359...    11  19.710342
# 3  [3.137358977338282, 0.6215729680939618, 3.0589...    23  44.756934
# 4  [3.030226348766256, -9.033719144629389e-2, 0.8...    25  48.649031

# %%
reg = EGGP(maxSize=25, gen=200, nPop=300, nonterminals="add,sub,mul,div,powerabs,recip", loss="MSE",
           loadFrom="seed.egraph", dumpTo="final.egraph")
reg.fit(X,y)
# Out:
# EGGP(dumpTo='final.egraph', gen=200, generational=0, loadFrom='seed.egraph',
#      maxSize=25, nPop=300, nonterminals='add,sub,mul,div,powerabs,recip',
#      simplify=0, trace=0)

# %%
reg.results
# Out:
#     id  view                                         Expression  \
# 0    0     0                                 0.5304279005524859
# 1    1     0                    (Abs(x0) ^ -0.1542389437304665)
# 2    2     0              (Abs(Recip(x0)) ^ 0.1542346398896011)
# 3    3     0  ((Abs(x0) ^ -0.2626705484577724) * 1.565348993...
# 4    4     0  (1.565836831559526 * ((Abs(x0) ^ -0.2276210658...
# 5    5     0  ((4.061580499555286e-2 - Recip((Abs(x0) ^ 0.23...
# 6    6     0  ((Abs((x0 / x1)) ^ -0.33985033838155326) + (0....
# 7    7     0  ((x1 / ((x0 / x1) + 7.193060239569831)) + (Abs...
# 8    8     0  ((x1 / ((x0 / x1) + 7.133649375518692)) + Reci...
# 9    9     0  ((x1 / ((x0 / x1) + 7.1649523915401865)) + (1....
# 10  10     0  ((13.103939841907469 / (17.660110286747308 + (...
# 11  11     0  ((13.000681200040871 / (17.445544898170283 + (...
# 12  12     0  ((4.102878392359119 / (x1 + (x0 / ((x1 + -3.64...
# 13  13     0  ((3.8327193847962184 / (x1 + (x0 / (1.00551707...
# 14  14     0  ((4.557801688984522 / (x1 + (0.918163464122120...
# 15  15     0  ((4.007068192404373 / (x1 + (x0 / (2.050331767...
# 16  16     0  ((5.290146030988929 / (x1 + (1.943689943770626...
# 17  17     0  (((x1 + 2.4007788051866124) / ((x1 + x1) + (x0...
#
#                                                 Numpy  \
# 0                                                t[0]
# 1                             np.abs(x[:, 0]) ** t[0]
# 2              np.abs(np.reciprocal(x[:, 0])) ** t[0]
# 3                    (np.abs(x[:, 0]) ** t[0] * t[1])
# 4           (t[0] * (np.abs(x[:, 0]) ** t[1] + t[2]))
# 5   ((t[0] - np.reciprocal(np.abs(x[:, 0]) ** t[1]...
# 6   (np.abs((x[:, 0] / x[:, 1])) ** t[0] + (t[1] /...
# 7   ((x[:, 1] / ((x[:, 0] / x[:, 1]) + t[0])) + np...
# 8   ((x[:, 1] / ((x[:, 0] / x[:, 1]) + t[0])) + np...
# 9   ((x[:, 1] / ((x[:, 0] / x[:, 1]) + t[0])) + (t...
# 10  ((t[0] / (t[1] + (x[:, 0] / (x[:, 1] + t[2])))...
# 11  ((t[0] / (t[1] + (x[:, 0] / (x[:, 1] + t[2])))...
# 12  ((t[0] / (x[:, 1] + (x[:, 0] / ((x[:, 1] + t[1...
# 13  ((t[0] / (x[:, 1] + (x[:, 0] / (t[1] + ((x[:, ...
# 14  ((t[0] / (x[:, 1] + (t[1] + (x[:, 0] / ((x[:, ...
# 15  ((t[0] / (x[:, 1] + (x[:, 0] / (t[1] + ((x[:, ...
# 16  ((t[0] / (x[:, 1] + (t[1] + (x[:, 0] / (((x[:,...
# 17  (((x[:, 1] + t[0]) / ((x[:, 1] + x[:, 1]) + (x...
#
#                                                 theta  size  loss_train  \
# 0                                  0.5304279005524859     1    0.025533
# 1                                 -0.1542389437304665     4    0.005466
# 2                                  0.1542346398896011     5    0.005466
# 3               -0.2626705484577724;1.565348993881181     6    0.001309
# 4   1.565836831559526;-0.2276210658980219;-5.07563...     8    0.001304
# 5   4.061580499555286e-2;0.23413907781083806;-1.56...     9    0.001303
# 6            -0.33985033838155326;0.49341119998380545    10    0.001191
# 7                7.193060239569831;0.7711572614761364    12    0.000919
# 8               7.133649375518692;-1.2441801671636448    12    0.000878
# 9   7.1649523915401865;1.0233385351825588;-1.17434...    13    0.000877
# 10  13.103939841907469;17.660110286747308;-3.32050...    14    0.000655
# 11  13.000681200040871;17.445544898170283;-3.32593...    16    0.000654
# 12  4.102878392359119;-3.648542518448178;-5.698432...    18    0.000372
# 13  3.8327193847962184;1.005517070486496;-3.878851...    19    0.000341
# 14  4.557801688984522;0.9181634641221208;-3.673966...    20    0.000312
# 15  4.007068192404373;2.0503317678990225;-4.154103...    21    0.000304
# 16  5.290146030988929;1.9436899437706268;-4.388432...    22    0.000289
# 17  2.4007788051866124;-10.97541502367868;0.531247...    23    0.000285
#
#     loss_val  loss_test   maxloss      R2_train        R2_val       R2_test  \
# 0   0.025533   0.025533  0.025533  1.554312e-15  1.554312e-15  1.554312e-15
# 1   0.005466   0.005466  0.005466  7.859255e-01  7.859255e-01  7.859255e-01
# 2   0.005466   0.005466  0.005466  7.859255e-01  7.859255e-01  7.859255e-01
# 3   0.001309   0.001309  0.001309  9.487450e-01  9.487450e-01  9.487450e-01
# 4   0.001304   0.001304  0.001304  9.489418e-01  9.489418e-01  9.489418e-01
# 5   0.001303   0.001303  0.001303  9.489532e-01  9.489532e-01  9.489532e-01
# 6   0.001191   0.001191  0.001191  9.533484e-01  9.533484e-01  9.533484e-01
# 7   0.000919   0.000919  0.000919  9.640009e-01  9.640009e-01  9.640009e-01
# 8   0.000878   0.000878  0.000878  9.656023e-01  9.656023e-01  9.656023e-01
# 9   0.000877   0.000877  0.000877  9.656544e-01  9.656544e-01  9.656544e-01
# 10  0.000655   0.000655  0.000655  9.743628e-01  9.743628e-01  9.743628e-01
# 11  0.000654   0.000654  0.000654  9.743699e-01  9.743699e-01  9.743699e-01
# 12  0.000372   0.000372  0.000372  9.854390e-01  9.854390e-01  9.854390e-01
# 13  0.000341   0.000341  0.000341  9.866571e-01  9.866571e-01  9.866571e-01
# 14  0.000312   0.000312  0.000312  9.877619e-01  9.877619e-01  9.877619e-01
# 15  0.000304   0.000304  0.000304  9.880949e-01  9.880949e-01  9.880949e-01
# 16  0.000289   0.000289  0.000289  9.886783e-01  9.886783e-01  9.886783e-01
# 17  0.000285   0.000285  0.000285  9.888262e-01  9.888262e-01  9.888262e-01
#
#     mdl_train    mdl_val   mdl_test
# 0    0.025533   0.025533   0.025533
# 1    3.301303   3.301303   3.301303
# 2    5.550643   5.550643   5.550643
# 3    6.932781   6.932781   6.932781
# 4   11.267369  11.267369  11.267369
# 5   14.335379  14.335379  14.335379
# 6   16.127026  16.127026  16.127026
# 7   19.710273  19.710273  19.710273
# 8   21.501992  21.501992  21.501992
# 9   20.923570  20.923570  20.923570
# 10  25.085287  25.085287  25.085287
# 11  28.668806  28.668806  28.668806
# 12  35.026754  35.026754  35.026754
# 13  34.043771  34.043771  34.043771
# 14  38.918515  38.918515  38.918515
# 15  37.627253  37.627253  37.627253
# 16  42.810312  42.810312  42.810312
# 17  37.017357  37.017357  37.017357

# %%
egfinal = Reggression(dataset="nikuradse_1.csv", loadFrom="final.egraph")
df = egfinal.top(5)
plot_error_seg(df, X, y)
# Out:
# Calculating DL...
# Welcome to r🥚ression

# %%
modulars = egfinal.modularity(5, filters=["> 5"])

print(modulars.Expression.values)
modulars
# Out:
# modularity 5 with size > 5 by fitness
# ['(t0 + (t1 / (((((t2 + x0) - (((t3 + x0) + x0) - x0)) - (((((t4 + x0) + x0) - x0) * (x0 + x0)) / (((t5 - x0) - x0) + x0))) * t6) + (x1 + t7))))'
#  '((((((t0 + x0) + t1) * t2) / ((((t3 + x0) + t4) * (x0 + x0)) / (t5 - x0))) / ((t6 - x0) * t7)) - (t8 * ((((t9 + x0) + t10) * t11) / ((((t12 + x0) + t13) * (x0 + x0)) / (t14 - x0)))))'
#  '((((((t0 + x0) * t1) / (((t2 + x0) / (t3 - x0)) * (x0 + x0))) * t4) / (t5 - x0)) - ((((t6 + x0) * t7) / (((t8 + x0) / (t9 - x0)) * (x0 + x0))) * t10))'
#  '(t0 / (((((t1 + x0) - (((t2 + x0) + x0) - x0)) - (((((t3 + x0) + x0) - x0) * (x0 + x0)) / (((t4 - x0) - x0) + x0))) * t5) + (x1 + t6)))'
#  '((((t0 / (x0 + 1.0)) + t1) - (t2 * (((t3 / (x0 + 1.0)) + t4) * ((t5 + x0) + 1.0)))) / ((((((t6 / x0) + t7) / (x0 + 1.0)) + t8) / x1) + t9))']
#     Id                                         Expression  \
# 0  398  (t0 + (t1 / (((((t2 + x0) - (((t3 + x0) + x0) ...
# 1  472  ((((((t0 + x0) + t1) * t2) / ((((t3 + x0) + t4...
# 2  533  ((((((t0 + x0) * t1) / (((t2 + x0) / (t3 - x0)...
# 3  397  (t0 / (((((t1 + x0) - (((t2 + x0) + x0) - x0))...
# 4  211  ((((t0 / (x0 + 1.0)) + t1) - (t2 * (((t3 / (x0...
#
#                                                Numpy   Fitness  \
# 0  (t[0] + (t[1] / (((((t[2] + x[:, 0]) - (((t[3]... -0.002712
# 1  ((((((t[0] + x[:, 0]) + t[1]) * t[2]) / ((((t[... -0.004233
# 2  ((((((t[0] + x[:, 0]) * t[1]) / (((t[2] + x[:,... -0.005027
# 3  (t[0] / (((((t[1] + x[:, 0]) - (((t[2] + x[:, ... -0.008320
# 4  ((((t[0] / (x[:, 0] + 1.0)) + t[1]) - (t[2] * ... -0.009468
#
#                                           Parameters  Size         DL
# 0  [0.31706152113829544, 3.0005971901046635, 0.36...    41  79.785028
# 1  [-0.13293280922489698, 0.31185904875547577, -1...    51  91.383966
# 2  [0.3178411165073354, 0.4234961684155471, -0.74...    43  77.050684
# 3  [3.5717512491591563, 0.3654710721360545, 0.139...    39  75.898815
# 4  [-0.39191399368972935, 0.7244267803967733, 9.9...    39  83.880277

# %%
egfinal.eqsat()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
modulars = egfinal.modularity(5, filters=["> 5"])

print(modulars.Expression.values)
modulars
# Out:
# modularity 5 with size > 5 by fitness
# ['(((x0 / ((t0 * x0) + t1)) - (((x0 / ((t2 * x0) + t3)) * ((t4 * x0) + t5)) * t6)) / ((((t7 / x0) / ((t8 * x0) + t9)) / x1) + t10))'
#  '((((((t0 + x0) + t1) * t2) / ((((t3 + x0) + t4) * (x0 + x0)) / (t5 - x0))) / ((t6 - x0) * t7)) - (t8 * ((((t9 + x0) + t10) * t11) / ((((t12 + x0) + t13) * (x0 + x0)) / (t14 - x0)))))'
#  '((((t0 + x0) / (((t1 + x0) / (t2 - x0)) * (t3 * x0))) / ((t4 - x0) * t5)) - (((t6 + x0) / (((t7 + x0) / (t8 - x0)) * (t9 * x0))) * t10))'
#  '(t0 - (((t1 + (x0 / ((t2 * x0) + t3))) - ((((t4 * x0) + t5) * (t6 + (x0 / ((t7 * x0) + t8)))) * t9)) / (((t10 + ((t11 / x0) / ((t12 * x0) + t13))) / x1) + t14)))'
#  '(((((((t0 + x0) + x0) / x0) * t1) + t2) * ((((((t3 + x0) + x0) / x0) * t4) + t5) * x0)) + t6)']
#     Id                                         Expression  \
# 0  297  (((x0 / ((t0 * x0) + t1)) - (((x0 / ((t2 * x0)...
# 1  472  ((((((t0 + x0) + t1) * t2) / ((((t3 + x0) + t4...
# 2  533  ((((t0 + x0) / (((t1 + x0) / (t2 - x0)) * (t3 ...
# 3  240  (t0 - (((t1 + (x0 / ((t2 * x0) + t3))) - ((((t...
# 4  382  (((((((t0 + x0) + x0) / x0) * t1) + t2) * ((((...
#
#                                                Numpy       Fitness  \
# 0  (((x[:, 0] / ((t[0] * x[:, 0]) + t[1])) - (((x...     -0.001969
# 1  ((((((t[0] + x[:, 0]) + t[1]) * t[2]) / ((((t[...     -0.004233
# 2  ((((t[0] + x[:, 0]) / (((t[1] + x[:, 0]) / (t[...     -0.004900
# 3  (t[0] - (((t[1] + (x[:, 0] / ((t[2] * x[:, 0])... -13465.929868
# 4  (((((((t[0] + x[:, 0]) + x[:, 0]) / x[:, 0]) *...     -0.008404
#
#                                           Parameters  Size            DL
# 0  [0.1266865893723914, -0.7377231636878416, -34....    37     72.000645
# 1  [-0.13293280922489698, 0.31185904875547577, -1...    51     91.383966
# 2  [-9.518974613675205e-2, 1.0209654078983912, 1....    39     69.883519
# 3  [0.5413485233412403, -0.4362556242813863, -0.6...    45  13553.495825
# 4  [-0.6027384788283144, -0.29343677556143993, 0....    27     43.463227
